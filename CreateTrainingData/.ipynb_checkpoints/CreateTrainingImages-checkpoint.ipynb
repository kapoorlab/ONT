# %% [markdown]
# # Create training images from csv file
# In this notebook, we create training images using the csv files generated by our MouseClick Fiji plugin which writes the event location as t,x,y,boolean format. The user has to input the image path used for creating the csv file along with the csv file. Other parameters to be specified by the user are indicated preceeding their respective blocks.

# %%
import numpy as np
import os
from glob import glob
from tifffile import imread 
import sys
sys.path.append("../NEAT")
from  NEATUtils import Augmentation2D
from NEATUtils import MovieCreator,npzfileGenerator
try:
    from pathlib import Path
    Path().expanduser()
except (ImportError,AttributeError):
    from pathlib2 import Path

try:
    import tempfile
    tempfile.TemporaryDirectory
except (ImportError,AttributeError):
    from backports import tempfile

# %% [markdown]
# In the block below specify the image used fore creating the csv files along with the total categories for classification.
#
# The default categories are: Norman events ,Macrocheate, NonMature and Mature P1 cells Apoptosis, Division .
#
# Crop size specifies the XY crop to be created at the location of the dot in the csv file and the third dimension is the crop in time relative to the click location, so it is X,Y Crops image area sizeX = -X/2:X/2, -Y/2:Y/2.
#
# Since the network learns the joint task of classification and localization, we need to create that anwser in the training data itself. Hence user specifies the value of shift in pixels to shift the event to, the program moves the event location from the center to nine locations (left, right, bottom, top, upper-left/right and bottom-left/right)
#
# The task of the program below is to create movie crops and assigned training label to each crop, labels used for events are:
#
# Normal Event: Label 0
#
# Macrocheate Event: Label 1
# Non MatureP1 Event : Label 2
# Mature Event: Label 3
# Apoptosis Event: Label 4
# Division Event: Label 5
#
# So for division in the center the training label would be
# [0,0,1,0,0,0.5,0.5]
# for the same event on the top Left
# [0,0,1,0,0,0.38,0.38] and so on. This task is done by the program automatically

# %%
#Specify the image used for making the csv file
SourceDir = '/home/sancere/VarunNewton/TrainingDataONEAT/CSVforNeat/NEATcsvfiles/'
SourceImage = imread(SourceDir + 'wt_N10.tif')
NormalCSV = SourceDir + 'Movie2Normal.csv'
ApoptosisCSV = SourceDir +  'wt_N10Apoptosis.csv'
DivisionCSV = SourceDir +  'wt_N10Division.csv'
MacrocheateCSV = SourceDir +  'Movie2MacroKitty.csv'
NonMatureCSV = SourceDir +  'Movie2NonMature.csv'
MatureCSV = SourceDir +  'Movie2Mature.csv'

Rawsave_dir = '/home/sancere/VarunNewton/TrainingDataONEAT/'
RawNormalsave_dir = Rawsave_dir + 'MidStaticNormalEventTrainingData'
RawApoptosissave_dir = Rawsave_dir + 'MidStaticMasterApoptosisEventTrainingData'
RawDivisionsave_dir = Rawsave_dir + 'MidStaticMasterDivisionEventTrainingData'
RawMacrocheatesave_dir = Rawsave_dir + 'MidStaticMacroKittyEventTrainingData'
RawNonMaturesave_dir = Rawsave_dir + 'MidStaticNonMatureP1EventTrainingData'
RawMaturesave_dir = Rawsave_dir + 'MidStaticMatureP1EventTrainingData'

Path(RawNormalsave_dir).mkdir(exist_ok = True)
Path(RawApoptosissave_dir).mkdir(exist_ok = True)
Path(RawDivisionsave_dir).mkdir(exist_ok = True)
Path(RawMacrocheatesave_dir).mkdir(exist_ok = True)
Path(RawNonMaturesave_dir).mkdir(exist_ok = True)
Path(RawMaturesave_dir).mkdir(exist_ok = True)

Localizationsave_dir = '/home/sancere/VarunNewton/CurieTrainingDatasets/Raw_Datasets/Neat/'
LocalizationNormalsave_dir = Localizationsave_dir +  'MidStaticNormalEventTrainingData'
LocalizationApoptosissave_dir = Localizationsave_dir + 'MidStaticMasterApoptosisEventTrainingData'
LocalizationDivisionsave_dir = Localizationsave_dir + 'MidStaticMasterDivisionEventTrainingData'
LocalizationMacrocheatesave_dir = Localizationsave_dir + 'MidStaticMacroKittyEventTrainingData'
LocalizationNonMaturesave_dir = Localizationsave_dir + 'MidStaticNonMatureP1EventTrainingData'
LocalizationMaturesave_dir = Localizationsave_dir +  'MidStaticMatureP1EventTrainingData'

Path(LocalizationNormalsave_dir).mkdir(exist_ok = True)
Path(LocalizationApoptosissave_dir).mkdir(exist_ok = True)
Path(LocalizationDivisionsave_dir).mkdir(exist_ok = True)
Path(LocalizationMacrocheatesave_dir).mkdir(exist_ok = True)
Path(LocalizationNonMaturesave_dir).mkdir(exist_ok = True)
Path(LocalizationMaturesave_dir).mkdir(exist_ok = True)

SaveNpzDirectory = '/home/sancere/VarunNewton/CurieTrainingDatasets/O-NEAT/'

crop_size = [64,64,-1]

#Shift the event by these many pixels
shift = 10
TotalCategories = 6
SizeX = crop_size[0]
SizeY = crop_size[1]

# %%
#For Normal Events/Negative controls
MovieCreator.CreateImagesTXYZ(NormalCSV, SourceImage, crop_size, 0,TotalCategories, 0 ,RawNormalsave_dir, 'ONEAT')
#For Macrocheate
MovieCreator.CreateImagesTXYZ(MacrocheateCSV, SourceImage, crop_size, shift,TotalCategories, 1 ,RawMacrocheatesave_dir, 'ONEAT')
#For NonMatureP1
MovieCreator.CreateImagesTXYZ(NonMatureCSV, SourceImage, crop_size, shift,TotalCategories, 2 ,RawNonMaturesave_dir, 'ONEAT')
#For MatureP1
MovieCreator.CreateImagesTXYZ(MatureCSV, SourceImage, crop_size, shift,TotalCategories, 3 ,RawMaturesave_dir, 'ONEAT')
#For Apoptosis
MovieCreator.CreateImagesTXYZ(ApoptosisCSV, SourceImage, crop_size, shift,TotalCategories, 4 ,RawApoptosissave_dir, 'ONEAT')
#For Division
MovieCreator.CreateImagesTXYZ(DivisionCSV, SourceImage, crop_size, shift,TotalCategories, 5 ,RawDivisionsave_dir, 'ONEAT')

# %%
#elasticDeform = True, putNoise (Blur) = True in that order
Subdir = next(os.walk(RawNormalsave_dir))

for x in Subdir[1]:
    currentdir = RawNormalsave_dir + '/' + x
    Augmentation2D(currentdir,LocalizationNormalsave_dir +'/' + x, SizeX, SizeY, False,True,AppendName = 'Master')
    
Subdir = next(os.walk(RawApoptosissave_dir))

for x in Subdir[1]:
    
    currentdir = RawApoptosissave_dir + '/' + x
    Augmentation2D(currentdir,LocalizationApoptosissave_dir +'/' + x, SizeX, SizeY, False,True,AppendName = 'Master') 
    
Subdir = next(os.walk(RawDivisionsave_dir))

for x in Subdir[1]:
    
    currentdir = RawDivisionsave_dir + '/' + x
    Augmentation2D(currentdir,LocalizationDivisionsave_dir +'/' + x, SizeX, SizeY, False,False,AppendName = 'Master') 
    
Subdir = next(os.walk(RawMacrocheatesave_dir))

for x in Subdir[1]:
    
    currentdir = RawMacrocheatesave_dir + '/' + x
    Augmentation2D(currentdir,LocalizationMacrocheatesave_dir +'/' + x, SizeX, SizeY, False,True,AppendName = 'Master') 

Subdir = next(os.walk(RawNonMaturesave_dir))

for x in Subdir[1]:
    
    currentdir = RawNonMaturesave_dir + '/' + x
    Augmentation2D(currentdir,LocalizationNonMaturesave_dir +'/' + x, SizeX, SizeY, False,True,AppendName = 'Master') 
    
Subdir = next(os.walk(RawMaturesave_dir))

for x in Subdir[1]:
    
    currentdir = RawMaturesave_dir + '/' + x
    Augmentation2D(currentdir,LocalizationMaturesave_dir +'/' + x, SizeX, SizeY, False,True,AppendName = 'Master')

# %%
DirectoryList = []
LabelList = []

Subdir = next(os.walk(LocalizationNormalsave_dir))

for x in Subdir[1]:
    currentdir = LocalizationNormalsave_dir + '/' + x
    CsvFile = sorted(glob(currentdir + '/' + '*.csv'))
    Labels = np.loadtxt(CsvFile[0], unpack = True)
    SubSubdir = next(os.walk(currentdir))
    for y in SubSubdir[1]:
        alldir = LocalizationNormalsave_dir + '/' + x + '/' + y+ '/'
        print(alldir)
        DirectoryList.append(alldir)
        LabelList.append(Labels)
        
Subdir = next(os.walk(LocalizationApoptosissave_dir))

for x in Subdir[1]:
    currentdir = LocalizationApoptosissave_dir + '/' + x 
    CsvFile = sorted(glob(currentdir + '/' + '*.csv'))
    
    Labels = np.loadtxt(CsvFile[0], unpack = True)
    SubSubdir = next(os.walk(currentdir))
    for y in SubSubdir[1]:
        alldir = LocalizationApoptosissave_dir + '/' + x + '/' + y+ '/'
        DirectoryList.append(alldir)
        LabelList.append(Labels)
        
Subdir = next(os.walk(LocalizationDivisionsave_dir))

for x in Subdir[1]:
    currentdir = LocalizationDivisionsave_dir + '/' + x 
    CsvFile = sorted(glob(currentdir + '/' + '*.csv'))
    print(currentdir,CsvFile)
    Labels = np.loadtxt(CsvFile[0], unpack = True)
    SubSubdir = next(os.walk(currentdir))
    for y in SubSubdir[1]:
        alldir = LocalizationDivisionsave_dir + '/' + x + '/' + y+ '/'
        DirectoryList.append(alldir)
        LabelList.append(Labels)
        
Subdir = next(os.walk(LocalizationMacrocheatesave_dir))

for x in Subdir[1]:
    currentdir = LocalizationMacrocheatesave_dir + '/' + x 
    CsvFile = sorted(glob(currentdir + '/' + '*.csv'))
    Labels = np.loadtxt(CsvFile[0], unpack = True)
    SubSubdir = next(os.walk(currentdir))
    for y in SubSubdir[1]:
        alldir = LocalizationMacrocheatesave_dir + '/' + x + '/' + y+ '/'
        DirectoryList.append(alldir)
        LabelList.append(Labels)
        
Subdir = next(os.walk(LocalizationNonMaturesave_dir))

for x in Subdir[1]:
    currentdir = LocalizationNonMaturesave_dir + '/' + x 
    CsvFile = sorted(glob(currentdir + '/' + '*.csv'))
    Labels = np.loadtxt(CsvFile[0], unpack = True)
    SubSubdir = next(os.walk(currentdir))
    for y in SubSubdir[1]:
        alldir = LocalizationNonMaturesave_dir + '/' + x + '/' + y+ '/'
        DirectoryList.append(alldir)
        LabelList.append(Labels)
        
Subdir = next(os.walk(LocalizationMaturesave_dir))

for x in Subdir[1]:
    currentdir = LocalizationMaturesave_dir + '/' + x 
    CsvFile = sorted(glob(currentdir + '/' + '*.csv'))
    Labels = np.loadtxt(CsvFile[0], unpack = True)
    SubSubdir = next(os.walk(currentdir))
    for y in SubSubdir[1]:
        alldir = LocalizationMaturesave_dir + '/' + x + '/' + y+ '/'
        DirectoryList.append(alldir)
        LabelList.append(Labels)
# Out:
# /home/sancere/VarunNewton/CurieTrainingDatasets/Raw_Datasets/Neat/MidStaticNormalEventTrainingData/NoShift/ResizeOriginal/
# /home/sancere/VarunNewton/CurieTrainingDatasets/Raw_Datasets/Neat/MidStaticNormalEventTrainingData/NoShift/Sigma1/
# /home/sancere/VarunNewton/CurieTrainingDatasets/Raw_Datasets/Neat/MidStaticMasterDivisionEventTrainingData/ShiftRXY ['/home/sancere/VarunNewton/CurieTrainingDatasets/Raw_Datasets/Neat/MidStaticMasterDivisionEventTrainingData/ShiftRXY/Label.csv']
# /home/sancere/VarunNewton/CurieTrainingDatasets/Raw_Datasets/Neat/MidStaticMasterDivisionEventTrainingData/ShiftDLXY ['/home/sancere/VarunNewton/CurieTrainingDatasets/Raw_Datasets/Neat/MidStaticMasterDivisionEventTrainingData/ShiftDLXY/Label.csv']
# /home/sancere/VarunNewton/CurieTrainingDatasets/Raw_Datasets/Neat/MidStaticMasterDivisionEventTrainingData/NoShift ['/home/sancere/VarunNewton/CurieTrainingDatasets/Raw_Datasets/Neat/MidStaticMasterDivisionEventTrainingData/NoShift/Label.csv']
# /home/sancere/VarunNewton/CurieTrainingDatasets/Raw_Datasets/Neat/MidStaticMasterDivisionEventTrainingData/ShiftDY ['/home/sancere/VarunNewton/CurieTrainingDatasets/Raw_Datasets/Neat/MidStaticMasterDivisionEventTrainingData/ShiftDY/Label.csv']
# /home/sancere/VarunNewton/CurieTrainingDatasets/Raw_Datasets/Neat/MidStaticMasterDivisionEventTrainingData/ShiftDRXY ['/home/sancere/VarunNewton/CurieTrainingDatasets/Raw_Datasets/Neat/MidStaticMasterDivisionEventTrainingData/ShiftDRXY/Label.csv']
# /home/sancere/VarunNewton/CurieTrainingDatasets/Raw_Datasets/Neat/MidStaticMasterDivisionEventTrainingData/ShiftLXY ['/home/sancere/VarunNewton/CurieTrainingDatasets/Raw_Datasets/Neat/MidStaticMasterDivisionEventTrainingData/ShiftLXY/Label.csv']
# /home/sancere/VarunNewton/CurieTrainingDatasets/Raw_Datasets/Neat/MidStaticMasterDivisionEventTrainingData/ShiftLX ['/home/sancere/VarunNewton/CurieTrainingDatasets/Raw_Datasets/Neat/MidStaticMasterDivisionEventTrainingData/ShiftLX/Label.csv']
# /home/sancere/VarunNewton/CurieTrainingDatasets/Raw_Datasets/Neat/MidStaticMasterDivisionEventTrainingData/ShiftRX ['/home/sancere/VarunNewton/CurieTrainingDatasets/Raw_Datasets/Neat/MidStaticMasterDivisionEventTrainingData/ShiftRX/Label.csv']
# /home/sancere/VarunNewton/CurieTrainingDatasets/Raw_Datasets/Neat/MidStaticMasterDivisionEventTrainingData/ShiftUY ['/home/sancere/VarunNewton/CurieTrainingDatasets/Raw_Datasets/Neat/MidStaticMasterDivisionEventTrainingData/ShiftUY/Label.csv']

# %%
SaveName = 'StaticMasterONEAT'
SaveNameVal = 'StaticMasterONEATValidation'


npzfileGenerator.generate_2D_training_data(DirectoryList, LabelList,SaveNpzDirectory, SaveName, SaveNameVal, SizeX, SizeY)
# Out:
# 100%|██████████| 278/278 [00:00<00:00, 1830.16it/s]
# 100%|██████████| 278/278 [00:00<00:00, 1908.46it/s]
# 100%|██████████| 1274/1274 [00:00<00:00, 1948.17it/s]
# 100%|██████████| 1274/1274 [00:00<00:00, 2029.83it/s]
# 100%|██████████| 1266/1266 [00:00<00:00, 1708.25it/s]
# 100%|██████████| 1266/1266 [00:00<00:00, 2021.95it/s]
# 100%|██████████| 1274/1274 [00:00<00:00, 1978.48it/s]
# 100%|██████████| 1274/1274 [00:00<00:00, 1996.97it/s]
# 100%|██████████| 1273/1273 [00:00<00:00, 1844.94it/s]
# 100%|██████████| 1273/1273 [00:00<00:00, 1781.42it/s]
# 100%|██████████| 1274/1274 [00:00<00:00, 1898.43it/s]
# 100%|██████████| 1274/1274 [00:00<00:00, 1941.70it/s]
# 100%|██████████| 1273/1273 [00:00<00:00, 2012.09it/s]
# 100%|██████████| 1273/1273 [00:00<00:00, 2045.47it/s]
# 100%|██████████| 1270/1270 [00:00<00:00, 2006.51it/s]
# 100%|██████████| 1270/1270 [00:00<00:00, 2056.40it/s]
# 100%|██████████| 1274/1274 [00:00<00:00, 1949.61it/s]
# 100%|██████████| 1274/1274 [00:00<00:00, 2026.71it/s]
# 100%|██████████| 1274/1274 [00:00<00:00, 1984.54it/s]
# 100%|██████████| 1274/1274 [00:00<00:00, 2020.86it/s]
# 100%|██████████| 11567/11567 [00:05<00:00, 2026.17it/s]
# 100%|██████████| 11587/11587 [00:06<00:00, 1893.75it/s]
# 100%|██████████| 11623/11623 [00:05<00:00, 2040.64it/s]
# 100%|██████████| 11564/11564 [00:05<00:00, 2025.70it/s]
# 100%|██████████| 11558/11558 [00:05<00:00, 2092.80it/s]
# 100%|██████████| 11588/11588 [00:05<00:00, 2038.39it/s]
# 100%|██████████| 11587/11587 [00:05<00:00, 2059.86it/s]
# 100%|██████████| 11564/11564 [00:05<00:00, 2060.65it/s]
# 100%|██████████| 11569/11569 [00:05<00:00, 1971.89it/s]
# 100%|██████████| 257/257 [00:00<00:00, 1811.31it/s]
# 100%|██████████| 257/257 [00:00<00:00, 1795.77it/s]
# 100%|██████████| 257/257 [00:00<00:00, 1742.59it/s]
# 100%|██████████| 257/257 [00:00<00:00, 1767.63it/s]
# 100%|██████████| 257/257 [00:00<00:00, 1806.28it/s]
# 100%|██████████| 257/257 [00:00<00:00, 1813.00it/s]
# 100%|██████████| 257/257 [00:00<00:00, 1807.16it/s]
# 100%|██████████| 257/257 [00:00<00:00, 1799.81it/s]
# 100%|██████████| 257/257 [00:00<00:00, 1713.69it/s]
# 100%|██████████| 257/257 [00:00<00:00, 1832.06it/s]
# 100%|██████████| 257/257 [00:00<00:00, 1838.15it/s]
# 100%|██████████| 257/257 [00:00<00:00, 1809.46it/s]
# 100%|██████████| 257/257 [00:00<00:00, 1666.63it/s]
# 100%|██████████| 257/257 [00:00<00:00, 1829.83it/s]
# 100%|██████████| 257/257 [00:00<00:00, 1762.33it/s]
# 100%|██████████| 257/257 [00:00<00:00, 1842.07it/s]
# 100%|██████████| 257/257 [00:00<00:00, 1831.07it/s]
# 100%|██████████| 257/257 [00:00<00:00, 1832.69it/s]
# 100%|██████████| 56/56 [00:00<00:00, 1255.92it/s]
# 100%|██████████| 56/56 [00:00<00:00, 1255.18it/s]
# 100%|██████████| 56/56 [00:00<00:00, 1219.90it/s]
# 100%|██████████| 56/56 [00:00<00:00, 1334.39it/s]
# 100%|██████████| 56/56 [00:00<00:00, 1363.83it/s]
# 100%|██████████| 56/56 [00:00<00:00, 1316.55it/s]
# 100%|██████████| 56/56 [00:00<00:00, 1254.34it/s]
# 100%|██████████| 56/56 [00:00<00:00, 1323.11it/s]
# 100%|██████████| 56/56 [00:00<00:00, 1330.21it/s]
# 100%|██████████| 56/56 [00:00<00:00, 1373.57it/s]
# 100%|██████████| 56/56 [00:00<00:00, 1158.26it/s]
# 100%|██████████| 56/56 [00:00<00:00, 1160.76it/s]
# 100%|██████████| 56/56 [00:00<00:00, 1336.40it/s]
# 100%|██████████| 56/56 [00:00<00:00, 1299.24it/s]
# 100%|██████████| 56/56 [00:00<00:00, 1261.97it/s]
# 100%|██████████| 56/56 [00:00<00:00, 1095.59it/s]
# 100%|██████████| 56/56 [00:00<00:00, 1339.12it/s]
# 100%|██████████| 56/56 [00:00<00:00, 1364.21it/s]
# 100%|██████████| 427/427 [00:00<00:00, 1867.23it/s]
# 100%|██████████| 427/427 [00:00<00:00, 1789.87it/s]
# 100%|██████████| 427/427 [00:00<00:00, 1883.31it/s]
# 100%|██████████| 427/427 [00:00<00:00, 1873.31it/s]
# 100%|██████████| 427/427 [00:00<00:00, 1722.63it/s]
# 100%|██████████| 427/427 [00:00<00:00, 1788.91it/s]
# 100%|██████████| 427/427 [00:00<00:00, 1897.90it/s]
# 100%|██████████| 427/427 [00:00<00:00, 1815.73it/s]
# 100%|██████████| 427/427 [00:00<00:00, 1898.83it/s]
# 100%|██████████| 427/427 [00:00<00:00, 1890.99it/s]
# 100%|██████████| 427/427 [00:00<00:00, 1865.08it/s]
# 100%|██████████| 427/427 [00:00<00:00, 1889.62it/s]
# 100%|██████████| 427/427 [00:00<00:00, 1855.11it/s]
# 100%|██████████| 427/427 [00:00<00:00, 1828.57it/s]
# 100%|██████████| 427/427 [00:00<00:00, 1909.37it/s]
# 100%|██████████| 427/427 [00:00<00:00, 1773.10it/s]
# 100%|██████████| 427/427 [00:00<00:00, 1937.30it/s]
# 100%|██████████| 427/427 [00:00<00:00, 1893.22it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-6badc948db42> in <module>
#       4 MovieFrames = 1
#       5
# ----> 6 npzfileGenerator.generate_2D_training_data(DirectoryList, LabelList,SaveNpzDirectory, SaveName, SaveNameVal,0, MovieFrames, SizeX, SizeY)
#
# ~/anaconda3/bin/ONT/NEAT/NEATUtils/npzfileGenerator.py in generate_2D_training_data(Masteroutputdir, Masterlabel, SaveNpzDirectory, SaveName, SaveNameVal, starttime, endtime, TrainshapeX, TrainshapeY)
#      92
#      93
# ---> 94                 dataarr = np.array(data)
#      95                 labelarr = np.array(label)
#      96
#
# ValueError: could not broadcast input array from shape (64,64,1) into shape (64,64)
